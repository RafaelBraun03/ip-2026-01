# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelBraun03/ip-2026-01/blob/main/Lista01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questão 1
#
# algoritmo "Aprovado ou reprovado"
#
#
#   var
#
#       nota1, nota2, nota3, media: real
#
#   inicio
#
#       escreva("Digite a primeira nota: ")
#      leia(nota1)
#
#      escreva("Digite a segunda nota: ")
#      leia(nota2)
#
#      escreva("Digite a terceira nota: ")
#      leia(nota3)
#
#      media <- (nota1 + nota2 + nota3) / 3
#
#      escreval("A média do aluno é: ", media)
#
#      se (media >= 7) entao
#          escreva("Status: Aprovado")
#      senao
#          escreva("Status: Reprovado")
#      fimse
#  fimalgoritmo

# %% [markdown]
# Questão 2
#
# Algoritmo "Arrecadaçaõ"
#
# Var
#
#    ingressos : inteiro
#
#    per_popular, per_geral, per_arquibancada, per_cadeiras, renda : real
#
# Inicio
#
#     escreva("Digite o número de ingressos: ")
#     leia(ingressos)
#
#     escreva("Digite a porcentagem de pessoas na categoria popular: ")
#     leia(per_popular)
#
#     escreva("Digite a porcentagem de pessoas na categoria geral: ")
#     leia(per_geral)
#
#     escreva("Digite a porcentagem de pessoas na categoria arquibancada: ")
#     leia(per_arquibancada)
#
#     escreva("Digite a porcentagem de pessoas na categoria cadeiras: ")
#     leia(per_cadeiras)
#
#     renda <- (per_popular*1 + per_geral*5 + per_arquibancada*10 + per_cadeiras*20)* ingressos/100
#
#     escreval("A renda do jogo é:", renda)
#
#
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 3
#
# Algoritmo "Composiçao Inteira"
#
#
# Var
#
#    n1, n2, n3, N, K : inteiro
#
#
# Inicio
#
#       escreva(n1)
#       leia(n1)
#
#       escreva(n2)
#       leia(n2)
#
#       escreva(n3)
#       leia(n3)
#
#       N <- n1*100 + n2*10 + n3
#       K <- N*N
#
#    se (n1 <= 0) ou (n1 >9) ou (n2 < 0) ou (n2 > 9) ou (n3 < 0) ou (n3 > 9) entao
#
#      escreva("Digito inválido")
#
#    senao
#
#        escreva(N, " ", K)
#
#    fimse
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 4
#
# Algoritmo "Consumo de energia"
#
#
# Var
#
#    salario, kw, custo_kw, custo_consumo, custo_desconto: real
#
#
# Inicio
#
#      escreva("Digite o valor do salário mínimo: ")
#      leia(salario)
#
#      escreva("Digite a quantidade de Kw gasto por uma residência: ")
#      leia(kw)
#
#      custo_kw <- salario*0.007
#
#      custo_consumo <- custo_kw * kw
#
#      custo_desconto <- custo_consumo*0.9
#
#      escreval("Custo po Kw: ", custo_kw)
#
#      escreval("Custo do consumo: ", custo_consumo)
#
#      escreval("Custo com desconto: ", custo_desconto)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 5
#
# Algoritmo "Conta de água"
#
#
# Var
#
#    u : inteiro
#
#    categoria : caracter
#
#    consumo, valor : real
#
# Inicio
#
#      escreva("Digite o identificador da conta: ")
#      leia(u)
#
#      escreva("Digite o consumo de água em metros cúbicos: ")
#      leia(consumo)
#
#      escreva("Digite o tipo de consumidor: ")
#      leia(categoria)
#
#     se(categoria = "R") entao
#       valor <- 5.00 + 0.05*consumo
#     senao
#        se(categoria = "C") entao
#           se(consumo <= 80.0) entao
#              valor <- 500.00
#           senao
#              valor <- 500 + 0.25*(consumo - 80.0)
#           fimse
#        senao
#           se(categoria = "I") entao
#              se (consumo <= 100.00) entao
#                valor <- 800.00
#              senao
#                valor <- 800.00 + (consumo - 100.00)*0.04
#              fimse
#           fimse
#        fimse
#     fimse
#
#     escreval("CONTA = ", u)
#     escreval("VALOR DA CONTA = ", valor)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 6
#
# Algoritmo "Conversão de temperatura"
#
#
# Var
#     f1, f2, f3, c1, c2, c3 : real
#
#
# Inicio
#
#        escreva("Digite a temperatura em  Fahrenheit : ")
#        leia(f1)
#
#        escreva("Digite a temperatura em  Fahrenheit : ")
#        leia(f2)
#
#        escreva("Digite a temperatura em  Fahrenheit : ")
#        leia(f3)
#
#       c1 <- (5*(f1 - 32))/9
#
#       c2 <- (5*(f2 - 32))/9
#
#       c3 <- (5*(f3 - 32))/9
#
#       escreval(f1, "FAHRENHEIT EQUIVALE A ", c1, " ", "CELSIUS")
#       escreval(f2, "FAHRENHEIT EQUIVALE A ", c2, " ", "CELSIUS")
#       escreval(f3, "FAHRENHEIT EQUIVALE A ", c3, " ", "CELSIUS")
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 7
#
# Algoritmo "Conversão para o sistema métrico"
#
# Var
#
#     f1, c1, chuva, volume : real
#
#
# Inicio
#
#        escreva("Digite a temperatura em  Fahrenheit : ")
#        leia(f1)
#
#        escreva("Digite a quantidade de chuva em polegadas: ")
#        leia(chuva)
#
#       volume <- chuva*25.4
#
#       c1 <- (5*(f1 - 32))/9
#
#       escreval("O valor em celsius é = ", c1)
#       escreval("A quantidade de chuva é = ", volume)
#
# fimalgoritmo

# %% [markdown]
# Questão 8
#
# Algoritmo "Custo da lata de cerveja"
#
#
# Var
#
#     r, h , custo : real
#
#
# Inicio
#
#        escreva("Digite o raio da lata: ")
#        leia(r)
#
#        escreva("Digite a altura da lata: ")
#        leia(h)
#
#
#        custo <- 100.00 * (2*3.14159*r*r + 2*3.14159* r * h)
#
#        escreval("O valor do custo é = ", custo)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 9
#
# Algoritmo "Cálculo do delta na equação de báskara"
#
#
# Var
#
#      a, b ,c , x : real
#
#
# Inicio
#
#         escreva("Digite o coeficiente A: ")
#         leia(a)
#
#         escreva("Digite o coeficiente B: ")
#         leia(b)
#
#         escreva("Digite o coeficiente C: ")
#         leia(c)
#
#         x <- b^2 - 4*(a*c)
#
#         escreval("O valor do delta é = ", x )
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 10
#
# Algoritmo "Determinante de uma matriz 2x2"
#
#
# Var
#
#      a, b, c, d , Det : real
#
# Inicio
#
#        escreva("Digite o elemento a da matriz: ")
#        leia(a)
#
#        escreva("Digite o elemento b da matriz: ")
#        leia(b)
#
#        escreva("Digite o elemento c da matriz: ")
#        leia(c)
#
#        escreva("Digite o elemento d da matriz: ")
#        leia(d)
#
#        Det <- a*d - b*c
#
#        escreval("O VALOR DO DETERMINANTE É = ", Det)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 11
#
# Algoritmo "Divisível po 3 e 5"
#
#
# Var
#
#    n : inteiro
#
#
# Inicio
#
#      escreva("Digite um número inteiro: ")
#      leia(n)
#
#      se (n % 3 = 0) e (n % 5 = 0) entao
#        escreval("O NÚMERO É DIVISÍVEL")
#       senao
#         escreval("O NÚMERO NÃO É DIVISÍVEL")
#      fimse
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 12
#
# Algoritmo "Locadora de charretes"
#
#
# Var
#
#      horas : inteiro
#      valor : real
#
# Inicio
#
#      escreva("Digite o número de horas que o locatário utilizou a charrete: ")
#      leia(horas)
#
#      valor <- (horas \ 3)*10.00 + (horas % 3)*5.00
#
#      escreval("O VALOR A PAGAR ﾉ = ", valor)
#
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 13
#
# Algoritmo "Conversão de nota em conceito"
#
#
# Var
#
#    nota : real
#
#    conceito : caracter
#
# Inicio
#
#      escreva("Digite o valor da nota: ")
#      leia(nota)
#
#      se(nota >= 0.0) e (nota < 6.0) entao
#        conceito <- "D"
#      senao
#         se(nota >= 6.0) e (nota < 7.5) entao
#           conceito <- "C"
#         senao
#            se (nota >= 7.5) e (nota < 9.0) entao
#             conceito <- "B"
#            senao
#              conceito <- "A"
#            fimse
#         fimse
#      fimse
#
#      escreval("NOTA = ", nota, " ", "CONCEITO = ", conceito)

# %% [markdown]
# Questão 14
#
# Algoritmo "Volume da pirâmide de base hexagonal"
#
#
# Var
#
#     h, a, volume : real
#
#
# Inicio
#
#        escreva("Digite a altura da pirâmide: ")
#        leia(h)
#
#        escreva("Digite a aresta da base hexagonal: ")
#        leia(a)
#
#        volume <- ((h*a*a)*3^0.5)/2
#
#        escreval("O VOLUME DA PIRAMIDE ﾉ: ", volume, "METROS CﾚBICOS")
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 15
#
# Algoritmo "Quadrado de pares"
#
# Var
#
#     n, x : inteiro
#
#
# Inicio
#
#        escreva("Digite um número N: ")
#        leia(n)
#
#        para x de 2 ate n faca
#        se (x % 2 = 0) e (n > 5) e (n < 2000) entao
#        escreval(x, "^2 = ", x*x)
#        fimse
#        fimpara
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 16
#
# Algoritmo "Reajuste salarial"
#
# Var
#
#      salario, final : real
#
#
# Inicio
#
#       escreva("Digite o salário do funcionário: ")
#       leia(salario)
#
#       se(salario <= 300.00) entao
#         final <- salario * 1.5
#       fimse
#
#       se (salario > 300.00) entao
#         final <- salario * 1.3
#       fimse
#
#       escreval("SALÁRIO COM REAJUSTE = ", final)
#
# Fimalgoritmo

# %% [markdown]
# Questão 17
#
# Algoritmo "Série de pares"
#
# Var
#
#    x, y, n : inteiro
#
#
# Inicio
#
#       escreva("Digite dois números: ")
#       leia(x,y)
#
#       se (x % 2 = 0) entao
#          para n de 1 ate y faca
#          escreva(x, " ")
#          x <- x + 2
#          fimpara
#       senao
#         escreva("O PRIMEIRO NÚMERO É IMPAR")
#       fimse
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 18
#
# Algoritmo "Soma de progressão aritmética"
#
# Var
#
#      a, r, n, S : real
#
#
# Inicio
#
#       escreva("Digite três números: "," ", " ")
#       leia(a, r, n)
#
#       S <- (n*(2*a + r*(n - 1)))/2
#
#       escreval(S)
#
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 19
#
# Algoritmo "Somatório simples"
#
#
# Var
#
#     n, k : inteiro
#     S : real
#
# Inicio
#
#         escreva("Digite um número inteiro: ")
#         leia(n)
#
#         se (n > 1) entao
#           S <- 0
#           para k de 1 ate n faca
#              S <- S + (1/k)
#           fimpara
#         senao
#         escreval("Número invalido")
#         fimse
#
#           escreval(S)
#
#
# Fimalgoritmo

# %% [markdown]
# Questão 20
#
# Algoritmo "Tempo em segundos"
#
#
# Var
#
#      h, m, s, T : inteiro
#
#
# Inicio
#
#        escreva("Digite o valor em horas: ")
#        leia(h)
#
#        escreva("Digite o valor em minutos :")
#        leia(m)
#
#        escreva("Digite o valor em segundos")
#        leia(s)
#
#        T <- h*3600 + m*60 + s
#
#        escreval("O TEMPO EM SEGUNDOS É: ", T)
#
# Fimalgoritmo
